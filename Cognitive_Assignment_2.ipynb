# %%
roll_no ="1024170333"
L = [int(digit) * 10 for digit in roll_no]
print("Initial List:", L)
# Out:
# Initial List: [10, 0, 20, 40, 10, 70, 0, 30, 30, 30]

# %%
L.append(50)
print("After append(50):", L)
# Out:
# After append(50): [10, 0, 20, 40, 10, 70, 0, 30, 30, 30, 50]

# %%
L.insert(2, 70)
print("After insert(2, 70):", L)
# Out:
# After insert(2, 70): [10, 0, 70, 20, 40, 10, 70, 0, 30, 30, 30, 50]

# %%
L.remove(50)
print("After remove(50):", L)
# Out:
# After remove(50): [10, 0, 70, 20, 40, 10, 70, 0, 30, 30, 30]

# %%
L.pop(2)
print("After pop(2):", L)
# Out:
# After pop(2): [10, 0, 20, 40, 10, 70, 0, 30, 30, 30]

# %%
L.sort()
print("Ascending Order:", L)
# Out:
# Ascending Order: [0, 0, 10, 10, 20, 30, 30, 30, 40, 70]

# %%
L.sort(reverse=True)
print("Descending Order:", L)
# Out:
# Descending Order: [70, 40, 30, 30, 30, 20, 10, 10, 0, 0]

# %%
print("First three elements:", L[:3])
print("Last three elements:", L[-3:])
# Out:
# First three elements: [70, 40, 30]
# Last three elements: [10, 0, 0]

# %%
average = sum(L) / len(L)

# %%
greater_than_average = [x for x in L if x > average]

print("Average:", average)
print("Elements greater than average:", greater_than_average)
# Out:
# Average: 24.0
# Elements greater than average: [70, 40, 30, 30, 30]

# %%
scores = tuple(L[:8])

print("Scores:", scores)
# Out:
# Scores: (70, 40, 30, 30, 30, 20, 10, 10)

# %%
highest = max(scores)
highest_index = scores.index(highest)
lowest = min(scores)
lowest_count = scores.count(lowest)
print("Highest score:", highest)
print("Index of highest score:", highest_index)
print("Lowest score:", lowest)
print("Number of times lowest score appears:", lowest_count)
# Out:
# Highest score: 70
# Index of highest score: 0
# Lowest score: 10
# Number of times lowest score appears: 2

# %%
reversed_scores = list(reversed(scores))

print("Reversed tuple as list:", reversed_scores)
# Out:
# Reversed tuple as list: [10, 10, 20, 30, 30, 30, 40, 70]

# %%
search_score = int(input("Enter a score to search: "))

if search_score in scores:
    print("First occurrence index:", scores.index(search_score))
else:
    print("Score not present in the tuple.")
# Out:
# Enter a score to search:  965
# Score not present in the tuple.

# %%
scores[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 scores[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
first_score, second_score, *remaining_scores = scores

print("First score:", first_score)
print("Second score:", second_score)
print("Remaining scores:", remaining_scores)
# Out:
# First score: 70
# Second score: 40
# Remaining scores: [30, 30, 30, 20, 10, 10]

# %%
import random

# %%
random.seed(1024170333)

# %%
numbers = [random.randint(100, 900) for _ in range(100)]
print("Random numbers:")
print(numbers)
# Out:
# Random numbers:
# [578, 572, 601, 273, 757, 366, 607, 101, 369, 558, 172, 110, 277, 791, 830, 186, 428, 231, 422, 315, 615, 167, 396, 417, 139, 580, 371, 290, 675, 233, 485, 291, 585, 311, 203, 545, 286, 790, 382, 659, 371, 841, 745, 342, 782, 586, 823, 268, 241, 590, 483, 874, 437, 222, 420, 645, 231, 407, 706, 524, 727, 388, 346, 423, 129, 816, 515, 260, 330, 313, 311, 564, 542, 158, 508, 578, 559, 382, 455, 664, 292, 160, 500, 151, 778, 631, 256, 697, 894, 107, 899, 117, 269, 652, 683, 437, 486, 290, 562, 213]

# %%
odd_numbers = [x for x in numbers if x % 2 != 0]
print("\nNumber of odd numbers:", len(odd_numbers))
print("Odd numbers:", odd_numbers)
# Out:
# Number of odd numbers: 52
# Odd numbers: [601, 273, 757, 607, 101, 369, 277, 791, 231, 315, 615, 167, 417, 139, 371, 675, 233, 485, 291, 585, 311, 203, 545, 659, 371, 841, 745, 823, 241, 483, 437, 645, 231, 407, 727, 423, 129, 515, 313, 311, 559, 455, 151, 631, 697, 107, 899, 117, 269, 683, 437, 213]

# %%
even_numbers = [x for x in numbers if x % 2 == 0]

print("\nNumber of even numbers:", len(even_numbers))
print("Even numbers:", even_numbers)
# Out:
# Number of even numbers: 48
# Even numbers: [578, 572, 366, 558, 172, 110, 830, 186, 428, 422, 396, 580, 290, 286, 790, 382, 342, 782, 586, 268, 590, 874, 222, 420, 706, 524, 388, 346, 816, 260, 330, 564, 542, 158, 508, 578, 382, 664, 292, 160, 500, 778, 256, 894, 652, 486, 290, 562]

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
            return True

# %%
prime_numbers = [x for x in numbers if is_prime(x)]

print("\nNumber of prime numbers:", len(prime_numbers))
print("Prime numbers:", prime_numbers)
# Out:
# Number of prime numbers: 0
# Prime numbers: []

# %%
most_frequent = max(set(numbers), key=numbers.count)
frequency = numbers.count(most_frequent)

print("\nMost frequent number:", most_frequent)
print("Number of occurrences:", frequency)
# Out:
# Most frequent number: 578
# Number of occurrences: 2

# %%
digits = [1, 0, 2, 4, 1, 7, 0, 3]

# %%
A = {digit * 7 for digit in digits}
B = {digit * 9 for digit in digits}
print("Set A:", A)
print("Set B:", B)
# Out:
# Set A: {0, 7, 14, 49, 21, 28}
# Set B: {0, 36, 9, 18, 27, 63}

# %%
union = A.union(B)
print("\nUnion of A and B:", union)
# Out:
# Union of A and B: {0, 36, 7, 9, 14, 49, 18, 21, 27, 28, 63}

# %%
intersection = A.intersection(B)
print("Intersection of A and B:", intersection)
# Out:
# Intersection of A and B: {0}

# %%
A_minus_B = A.difference(B)
B_minus_A = B.difference(A)
print("A - B=", A_minus_B)
print("B - A=", B_minus_A)
# Out:
# A - B= {7, 14, 49, 21, 28}
# B - A= {36, 9, 18, 27, 63}

# %%
symmetric_diff = A.symmetric_difference(B)
print("Symmetric Difference =", symmetric_diff)
# Out:
# Symmetric Difference = {7, 9, 14, 18, 21, 27, 28, 36, 49, 63}

# %%
print("Is A a subset of B is", A.issubset(B))
print("Is B a superset of A is", B.issuperset(A))
# Out:
# Is A a subset of B is False
# Is B a superset of A is False

# %%
X = int(input("\nEnter a value to remove from set A: "))
A.discard(X)
print("Set A after discard:", A)
# Out:
# Enter a value to remove from set A:  14
# Set A after discard: {0, 7, 49, 21, 28}

# %%
my_dict = {
    "name": "Sahil",
    "roll_no": "1024170333",
    "branch": "CSE",
    "age": 21,
    "city": "Patiala"
}
print("Original dictionary:")
print(my_dict)
# Out:
# Original dictionary:
# {'name': 'Sahil', 'roll_no': '1024170333', 'branch': 'CSE', 'age': 21, 'city': 'Patiala'}

# %%
my_dict["location"] = my_dict.pop("city")

# %%
my_dict["cgpa"] = 8.11
print("\nAfter renaming city and adding CGPA:")
print(my_dict)
# Out:
# After renaming city and adding CGPA:
# {'name': 'Sahil', 'roll_no': '1024170333', 'branch': 'CSE', 'age': 21, 'location': 'Patiala', 'cgpa': 8.11}

# %%
my_dict["age"] += 1
print("\nAfter increasing age by 1:")
print(my_dict)
# Out:
# After increasing age by 1:
# {'name': 'Sahil', 'roll_no': '1024170333', 'branch': 'CSE', 'age': 22, 'location': 'Patiala', 'cgpa': 8.11}

# %%
dict_pop = my_dict.copy()
removed_branch = dict_pop.pop("branch")
print("\nUsing pop():")
print("Removed value:", removed_branch)
print("Dictionary:", dict_pop)
# Out:
# Using pop():
# Removed value: CSE
# Dictionary: {'name': 'Sahil', 'roll_no': '1024170333', 'age': 22, 'location': 'Patiala', 'cgpa': 8.11}

# %%
dict_del = my_dict.copy()
del dict_del["branch"]
print("\nUsing del:")
print("Dictionary:", dict_del)
# Out:
# Using del:
# Dictionary: {'name': 'Sahil', 'roll_no': '1024170333', 'age': 22, 'location': 'Patiala', 'cgpa': 8.11}

# %%
print("\nKey-value pairs:")
for key, value in my_dict.items():
    print(f"{key} → {value}")
# Out:
# Key-value pairs:
# name → Sahil
# roll_no → 1024170333
# branch → CSE
# age → 22
# location → Patiala
# cgpa → 8.11

# %%
if "email" in my_dict:
    print("\nEmail:", my_dict["email"])
else:
    print("\nEmail key is not present in the dictionary.")
# Out:
# Email key is not present in the dictionary.

# %%
friend_dict = {
    "name": "Rahul",
    "roll_no": "1024170334",
    "branch": "CSE",
    "age": 21,
    "city": "Chandigarh"
}

# %%
merged_dict = {**my_dict, **friend_dict}

print("\nMerged dictionary:")
print(merged_dict)
# Out:
# Merged dictionary:
# {'name': 'Rahul', 'roll_no': '1024170334', 'branch': 'CSE', 'age': 21, 'location': 'Patiala', 'cgpa': 8.11, 'city': 'Chandigarh'}

# %%
string_values = {
    key: value
    for key, value in my_dict.items()
    if isinstance(value, str)
}
print("\nDictionary containing only string values:")
print(string_values)
# Out:
# Dictionary containing only string values:
# {'name': 'Sahil', 'roll_no': '1024170333', 'branch': 'CSE', 'location': 'Patiala'}
